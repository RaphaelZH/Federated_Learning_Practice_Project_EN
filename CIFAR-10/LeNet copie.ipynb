# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Importation des bibliothèques](#toc1_)
#   - [Importation des paquets ou modules de la bibliothèque OpenFL](#toc1_1_)
#   - [Importation des paquets ou modules de la bibliothèque PyTorch](#toc1_2_)
#   - [Importation d’autres paquets ou modules requis](#toc1_3_)
# - [Définition du modèle d‘entraînement](#toc2_)
#   - [Définition des chargeurs de données](#toc2_1_)
#   - [Définition du modèle de réseau CNN](#toc2_2_)
#   - [Définition de la fonction d'inférence utilisée dans le test](#toc2_3_)
# - [Définition des règles de l'apprentissage fédéré](#toc3_)
#   - [Méthode de calcul de la moyenne des poids d'apprentissage fédéré](#toc3_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Importation des bibliothèques](#toc0_)
#
# ## <a id='toc1_1_'></a>[Importation des paquets ou modules de la bibliothèque OpenFL](#toc0_)

# %%
from openfl.experimental.workflow.interface import Aggregator, Collaborator, FLSpec
from openfl.experimental.workflow.placement import aggregator, collaborator
from openfl.experimental.workflow.runtime import LocalRuntime

# %% [markdown]
# ## <a id='toc1_2_'></a>[Importation des paquets ou modules de la bibliothèque PyTorch](#toc0_)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

from torchsummary import summary

from torchvision import datasets, transforms

# %% [markdown]
# ## <a id='toc1_3_'></a>[Importation d’autres paquets ou modules requis](#toc0_)

# %%
from copy import deepcopy

import numpy as np

from termcolor import cprint

# %% [markdown]
# # <a id='toc2_'></a>[Définition du modèle d‘entraînement](#toc0_)
#
# ## <a id='toc2_1_'></a>[Définition des chargeurs de données](#toc0_)

# %%
data_path = "/tmp/files/"

tensor_cifar10 = datasets.CIFAR10(
    data_path, train=True, download=True, transform=transforms.ToTensor()
)

tensor_images = torch.stack([tensor_image for tensor_image, _ in tensor_cifar10], dim=3)

tensor_images.shape
# Out:
# torch.Size([3, 32, 32, 50000])

# %%
tensor_mean = tensor_images.view(3, -1).mean(dim=1)
tensor_mean
# Out:
# tensor([0.4914, 0.4822, 0.4465])

# %%
tensor_std = tensor_images.view(3, -1).std(dim=1)
tensor_std
# Out:
# tensor([0.2470, 0.2435, 0.2616])

# %%
transform_train = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(10),
        transforms.RandomAffine(0, shear=10, scale=(0.8, 1.2)),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.ToTensor(),
        transforms.Normalize(tensor_mean, tensor_std),
    ]
)


transform_test = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
        transforms.Normalize(tensor_mean, tensor_std),
    ]
)

cifar10_train = datasets.CIFAR10(
    "/tmp/files/",
    train=True,
    download=True,
    transform=transform_train,
)

cifar10_test = datasets.CIFAR10(
    "/tmp/files/",
    train=False,
    download=True,
    transform=transform_test,
)

# %% [markdown]
# ## <a id='toc2_2_'></a>[Définition du modèle de réseau CNN](#toc0_)

# %%
if torch.backends.mps.is_available():
    cprint("MPS is available", "green")
    device = torch.device("mps:0")
elif torch.backends.cuda.is_available():
    cprint("CUDA is available", "green")
    device = torch.device("cuda:0")
elif torch.backends.cudnn.is_built():
    cprint("CUDNN is available", "green")
    device = torch.device("cuda:0")
else:
    cprint("CUDA and MPS are not available", "red")
    cprint("Using CPU", "red")
    device = torch.device("cpu")
# Out:
# MPS is available

# %%
class LeNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        self.fc1 = nn.Linear(4 * 4 * 64, 500)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4 * 4 * 64)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
model = LeNet()
summary(model, next(iter(cifar10_test))[0].shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#             Conv2d-2           [-1, 32, 16, 16]           4,640
#             Conv2d-3             [-1, 64, 8, 8]          18,496
#             Linear-4                  [-1, 500]         512,500
#            Dropout-5                  [-1, 500]               0
#             Linear-6                   [-1, 10]           5,010
# ================================================================
# Total params: 541,094
# Trainable params: 541,094
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.23
# Params size (MB): 2.06
# Estimated Total Size (MB): 2.30
# ----------------------------------------------------------------

# %%
def count_parameters(model):
    length = 67
    names = [n for (n, p) in model.named_parameters() if p.requires_grad]
    name = "total parameters"
    names.append(name)
    max_length = max(map(len, names))
    formatted_names = [f"{f'  {n} ':.<{max_length + 3}}" for n in names]
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    params.append(sum(params))
    formatted_params = [f"{f' {p}  ':.>{length - max_length - 3}}" for p in params]

    for n, p in zip(formatted_names[:-1], formatted_params[:-1]):
        cprint((n + p), "magenta")
    cprint(" " + "_" * (length - 2) + " ", "magenta")
    cprint(
        (formatted_names[-1] + formatted_params[-1]),
        "magenta",
        end="\n\n",
    )

    return names, params


names, params = count_parameters(model)
# Out:
#   conv1.weight .............................................. 432
#   conv1.bias ................................................. 16
#   conv2.weight ............................................. 4608
#   conv2.bias ................................................. 32
#   conv3.weight ............................................ 18432
#   conv3.bias ................................................. 64
#   fc1.weight ............................................. 512000
#   fc1.bias .................................................. 500
#   fc2.weight ............................................... 5000
#   fc2.bias ................................................... 10
#  _________________________________________________________________
#   total parameters ....................................... 541094

# %% [markdown]
# ## <a id='toc2_3_'></a>[Définition de la fonction d'inférence utilisée dans le test](#toc0_)

# %%
def inference(network, test_loader):
    # Mettre le module en mode évaluation.
    network.eval()
    network.to(device)
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = network(data)
            test_loss += F.cross_entropy(output, target, reduction="sum").item()
            pred = output.data.max(dim=1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    test_loss /= len(test_loader.dataset)
    cprint(
        "Test set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)".format(
            test_loss,
            correct,
            len(test_loader.dataset),
            100.0 * correct / len(test_loader.dataset),
        ),
        "magenta",
        attrs=["underline"],
        end="\n\n",
    )
    return float(correct / len(test_loader.dataset))

# %%
test_loader = DataLoader(cifar10_test, batch_size=500, shuffle=False)

inference(model, test_loader)
# Out:
# Test set: Avg. loss: 2.3027, Accuracy: 968/10000 (10%)
# 0.09679999947547913

# %% [markdown]
# # <a id='toc3_'></a>[Définition des règles de l'apprentissage fédéré](#toc0_)
#
# ## <a id='toc3_1_'></a>[Méthode de calcul de la moyenne des poids d'apprentissage fédéré](#toc0_)

# %%
def FedAvg(models, weights=None):
    new_model = models[0]
    state_dicts = [model.state_dict() for model in models]
    state_dict = new_model.state_dict()
    for key in models[1].state_dict():
        if state_dict[key].dim() != 0:
            state_dict[key] = torch.from_numpy(
                np.average(
                    [state[key].cpu().numpy() for state in state_dicts],
                    axis=0,
                    weights=weights,
                )
            )
        else:
            state_dict[key] = torch.from_numpy(
                np.average(
                    [state[key].reshape(1).cpu().numpy() for state in state_dicts],
                    axis=0,
                    weights=weights,
                )
            )
    new_model.load_state_dict(state_dict)
    return new_model

# %%
learning_rate = 0.01
log_interval = 10
momentum = 0.5


class FederatedFlow(FLSpec):

    def __init__(self, model=None, optimizer=None, rounds=3, **kwargs):
        super().__init__(**kwargs)
        # Importe un modèle personnalisé et ajoute le bon algorithme d’optimisation pour ce dernier.
        if model is not None:
            self.model = model
            self.optimizer = optimizer
        # Chargez le modèle `Net()` et configurez l'optimiseur pour qu'il s'applique uniquement à ce
        # modèle.
        else:
            self.model = Net()
            self.optimizer = optim.SGD(
                self.model.parameters(), lr=learning_rate, momentum=momentum
            )
        self.rounds = rounds

    # Un agrégateur est le nœud central de l'apprentissage fédéré.

    # L'agrégateur commence par un modèle et un optimiseur transmis de manière facultative.

    # L'agrégateur commence le flux avec la tâche de `start`, où la liste des collaborateurs est
    # extraite de l'exécution (`self.collaborators = self.runtime.collaborators`) et est ensuite
    # utilisée comme liste de participants pour exécuterla tâche énumérée dans `self.next`,
    # `aggregated_model_validation`.
    @aggregator
    def start(self):
        cprint("Performing initialization for model", "black", attrs=["bold"])
        self.collaborators = self.runtime.collaborators
        self.private = 10
        self.current_round = 0
        self.next(
            self.aggregated_model_validation,
            foreach="collaborators",
            exclude=["private"],
        )

    # Le modèle, l'optimiseur et tout ce qui n'est pas explicitement exclu de la fonction suivante
    # seront transmis de la fonction de `start` de l'agrégateur à la tâche
    # `aggregated_model_validation` du collaborateur.

    # L’endroit où les tâches sont exécutées est déterminé par le décorateur de placement qui
    # précède chaque définition de tâche (`@aggregator` ou `@collaborator`).

    # Une fois que chaque collaborateur (défini dans l’exécution) a terminé la tâche
    # `aggregated_model_validation`, il transmet son état actuel à la tâche `train`, de `train` à
    # `local_model_validation`, et enfin à `join` à l'agrégateur.

    # C'est au niveau de `join` qu'une moyenne des poids des modèles est calculée et que le tour
    # suivant peut commencer.
    @collaborator
    def aggregated_model_validation(self):
        cprint(
            f"Performing aggregated model validation for collaborator {self.input}",
            "red",
            attrs=["bold"],
        )
        self.agg_validation_score = inference(self.model, self.test_loader)
        cprint(
            f"{self.input} value of {self.agg_validation_score}",
            "red",
            attrs=["underline"],
        )
        self.next(self.train)

    @collaborator
    def train(self):
        if model is not None:
            self.model = model
            self.optimizer = optimizer
        else:
            self.model = Net()
            self.optimizer = optim.SGD(
                self.model.parameters(), lr=learning_rate, momentum=momentum
            )
        self.model.train()
        for batch_idx, (data, target) in enumerate(self.train_loader):
            data, target = data.to(device), target.to(device)
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = F.cross_entropy(output, target)
            loss.backward()
            self.optimizer.step()
            if batch_idx % log_interval == 0:
                cprint(
                    "Train Epoch: 1 [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                        batch_idx * len(data),
                        len(self.train_loader.dataset),
                        100.0 * batch_idx / len(self.train_loader),
                        loss.item(),
                    ),
                    "yellow",
                )
                self.loss = loss.item()
                torch.save(self.model.state_dict(), "model.pth")
                torch.save(self.optimizer.state_dict(), "optimizer.pth")
        self.training_completed = True
        self.next(self.local_model_validation)

    @collaborator
    def local_model_validation(self):
        self.local_validation_score = inference(self.model, self.test_loader)
        cprint(
            f"Doing local model validation for collaborator {self.input}: \
                {self.local_validation_score}",
            "white",
        )
        self.next(self.join, exclude=["training_completed"])

    @aggregator
    def join(self, inputs):
        self.average_loss = sum(input.loss for input in inputs) / len(inputs)
        self.aggregated_model_accuracy = sum(
            input.agg_validation_score for input in inputs
        ) / len(inputs)
        self.local_model_accuracy = sum(
            input.local_validation_score for input in inputs
        ) / len(inputs)
        cprint(
            f"Average aggregated model validation values = \
                {self.aggregated_model_accuracy}",
            "green",
        )
        cprint(f"Average training loss = {self.average_loss}", "green")
        cprint(
            f"Average local model validation values = \
            {self.local_model_accuracy}",
            "green",
        )
        self.model = FedAvg([input.model for input in inputs])
        self.optimizer = [input.optimizer for input in inputs][0]
        self.current_round += 1
        if self.current_round < self.rounds:
            self.next(
                self.aggregated_model_validation,
                foreach="collaborators",
                exclude=["private"],
            )
        else:
            self.next(self.end)

    @aggregator
    def end(self):
        cprint("This is the end of the flow", "black")
# Out:
# Aggregator step "start" registered
# Collaborator step "aggregated_model_validation" registered
# Collaborator step "train" registered
# Collaborator step "local_model_validation" registered
# Aggregator step "join" registered
# Aggregator step "end" registered

# %%
random_seed = 1
torch.manual_seed(random_seed)

# %%
batch_size_train = 64

# Setup participants
aggregator = Aggregator()
aggregator.private_attributes = {}

# Setup collaborators with private attributes
collaborator_names = ["Portland", "Seattle", "Chandler", "Bangalore"]
collaborators = [Collaborator(name=name) for name in collaborator_names]
for idx, collaborator in enumerate(collaborators):
    local_train = deepcopy(cifar10_train)
    local_test = deepcopy(cifar10_test)
    local_train.data = cifar10_train.data[idx :: len(collaborators)]
    local_train.targets = cifar10_train.targets[idx :: len(collaborators)]
    local_test.data = cifar10_test.data[idx :: len(collaborators)]
    local_test.targets = cifar10_test.targets[idx :: len(collaborators)]
    collaborator.private_attributes = {
        "train_loader": DataLoader(
            local_train, batch_size=batch_size_train, shuffle=True
        ),
        "test_loader": DataLoader(
            local_test, batch_size=batch_size_train, shuffle=True
        ),
    }

local_runtime = LocalRuntime(
    aggregator=aggregator, collaborators=collaborators, backend="single_process"
)
print(f"Local runtime collaborators = {local_runtime.collaborators}")
# Out:
# Local runtime collaborators = ['Portland', 'Seattle', 'Chandler', 'Bangalore']

# %%
import os
if os.environ.get("USERNAME") is None:
    os.environ["USERNAME"] = "Hao"

# %%
import getpass
print(getpass.getuser())
# Out:
# haozhang

# %%
learning_rate = 0.001
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
flflow = FederatedFlow(model, optimizer, rounds=10, checkpoint=True)
flflow.runtime = local_runtime
flflow.run()
# Out:
# Created flow FederatedFlow
#
# Calling start
# Performing initialization for model
# Saving data artifacts for start
# Saved data artifacts for start
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 2.3023, Accuracy: 230/2500 (9%)
#
# Portland value of 0.09200000017881393
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 2.303839
# Train Epoch: 1 [640/12500 (5%)]	Loss: 2.267011
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 2.190468
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 2.009020
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 2.102379
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 2.069176
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.988785
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.902983
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.805575
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.944189
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.919294
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.938501
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.964217
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.843731
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.833329
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.731591
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.743492
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.752015
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.537894
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.590503
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.5842, Accuracy: 1063/2500 (43%)
#
# Doing local model validation for collaborator Portland:                 0.4251999855041504
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 2.3028, Accuracy: 235/2500 (9%)
#
# Seattle value of 0.09399999678134918
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.870081
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.782940
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.852658
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.641154
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.501457
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.603513
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.801847
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.447641
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.684561
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.548303
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.592670
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.808466
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.558152
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.667401
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.690103
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.682831
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.690095
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.469613
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.778627
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.553958
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.4517, Accuracy: 1169/2500 (47%)
#
# Doing local model validation for collaborator Seattle:                 0.4675999879837036
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 2.3040, Accuracy: 235/2500 (9%)
#
# Chandler value of 0.09399999678134918
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.499150
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.435242
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.608138
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.409011
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.433497
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.757825
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.403058
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.430393
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.391592
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.502044
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.423404
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.340664
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.307706
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.281121
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.704812
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.502986
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.530243
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.409431
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.407086
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.544866
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.3837, Accuracy: 1223/2500 (49%)
#
# Doing local model validation for collaborator Chandler:                 0.48919999599456787
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 2.3018, Accuracy: 268/2500 (11%)
#
# Bangalore value of 0.10719999670982361
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.577879
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.200411
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.629262
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.415122
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.646214
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.347262
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.280733
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.443208
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.266913
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.416071
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.443138
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.326712
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.445666
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.462683
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.578424
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.494435
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.138315
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.434401
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.566066
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.466942
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.2946, Accuracy: 1311/2500 (52%)
#
# Doing local model validation for collaborator Bangalore:                 0.524399995803833
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.09679999761283398
# Average training loss = 1.5390670895576477
# Average local model validation values =             0.4765999913215637
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 1.2851, Accuracy: 1338/2500 (54%)
#
# Portland value of 0.5351999998092651
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.280861
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.568423
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.558010
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.507191
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.511450
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.323541
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.375017
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.233613
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.413285
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.197012
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.243169
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.187171
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.440372
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.259956
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.178971
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.225369
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.474598
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.435137
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.499087
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.478898
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.2055, Accuracy: 1405/2500 (56%)
#
# Doing local model validation for collaborator Portland:                 0.5619999766349792
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 1.3305, Accuracy: 1242/2500 (50%)
#
# Seattle value of 0.4968000054359436
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.306051
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.215562
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.174201
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.246056
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.482873
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.459411
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.304369
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.511445
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.176374
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.288604
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.323102
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.586197
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.151526
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.432068
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.347648
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.329263
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.353461
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.360672
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.398207
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.527575
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1938, Accuracy: 1436/2500 (57%)
#
# Doing local model validation for collaborator Seattle:                 0.574400007724762
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 1.3361, Accuracy: 1224/2500 (49%)
#
# Chandler value of 0.4896000027656555
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.397851
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.382468
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.339800
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.349062
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.341906
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.334823
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.216334
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.234901
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.350725
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.305360
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.165649
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.475273
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.306727
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.262682
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.297524
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.599766
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.108672
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.100669
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.296404
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.217940
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1492, Accuracy: 1437/2500 (57%)
#
# Doing local model validation for collaborator Chandler:                 0.5748000144958496
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 1.2946, Accuracy: 1311/2500 (52%)
#
# Bangalore value of 0.524399995803833
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.256933
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.170769
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.272248
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.303532
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.026278
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.472070
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.278093
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.961633
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.194239
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.166486
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.443881
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.055282
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.290839
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.355610
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.351127
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.417136
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.325067
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.134556
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.227954
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.350265
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1025, Accuracy: 1509/2500 (60%)
#
# Doing local model validation for collaborator Bangalore:                 0.603600025177002
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.5115000009536743
# Average training loss = 1.393669456243515
# Average local model validation values =             0.5787000060081482
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 1.1049, Accuracy: 1514/2500 (61%)
#
# Portland value of 0.6055999994277954
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.230240
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.158635
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.241762
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.231708
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.044858
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.247226
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.083909
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.454051
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.333635
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.473184
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.933482
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.116665
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.376184
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.218166
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.142555
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.311019
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.105185
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.098191
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.018623
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.276493
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.0689, Accuracy: 1550/2500 (62%)
#
# Doing local model validation for collaborator Portland:                 0.6200000047683716
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 1.1278, Accuracy: 1471/2500 (59%)
#
# Seattle value of 0.5884000062942505
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.450777
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.095973
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.064825
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.336969
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.132233
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.311541
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.096924
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.336173
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.190191
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.313693
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.466823
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.017593
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.090634
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.194188
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.979401
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.335253
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.301513
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.067040
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.248361
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.024100
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.0714, Accuracy: 1574/2500 (63%)
#
# Doing local model validation for collaborator Seattle:                 0.6295999884605408
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 1.1267, Accuracy: 1465/2500 (59%)
#
# Chandler value of 0.5860000252723694
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.201176
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.189060
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.053469
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.167327
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.227142
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.281131
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.196039
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.046934
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.210069
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.014658
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.156496
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.964236
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.132628
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.159793
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.237261
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.474423
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.288686
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.136652
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.346724
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.015312
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.0403, Accuracy: 1550/2500 (62%)
#
# Doing local model validation for collaborator Chandler:                 0.6200000047683716
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 1.1025, Accuracy: 1509/2500 (60%)
#
# Bangalore value of 0.603600025177002
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.314235
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.401584
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.112201
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.265105
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.420858
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.230010
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.335877
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.044153
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.050767
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.188771
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.331067
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.023864
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.845835
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.176738
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.061505
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.159986
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.077017
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.073945
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.215411
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.052531
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9791, Accuracy: 1622/2500 (65%)
#
# Doing local model validation for collaborator Bangalore:                 0.6488000154495239
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.5959000140428543
# Average training loss = 1.0921090245246887
# Average local model validation values =             0.629600003361702
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 1.0007, Accuracy: 1616/2500 (65%)
#
# Portland value of 0.646399974822998
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.131278
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.059052
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.930494
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.133672
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.111339
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.365617
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.112000
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.582942
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.034355
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.021636
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.986020
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.937506
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.398273
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.048805
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.158669
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.143575
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.308743
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.973059
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.030378
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.096269
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9860, Accuracy: 1625/2500 (65%)
#
# Doing local model validation for collaborator Portland:                 0.6499999761581421
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 1.0130, Accuracy: 1606/2500 (64%)
#
# Seattle value of 0.6424000263214111
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.935099
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.152567
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.088676
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.211678
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.965043
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.119537
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.169707
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.215160
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.263552
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.168699
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.899809
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.260543
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.962561
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.067629
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.204854
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.157452
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.256075
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.963740
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.131261
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.105306
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9965, Accuracy: 1649/2500 (66%)
#
# Doing local model validation for collaborator Seattle:                 0.659600019454956
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 1.0165, Accuracy: 1586/2500 (63%)
#
# Chandler value of 0.6344000101089478
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.148758
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.091687
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.996478
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.167780
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.099782
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.838446
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.101618
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.314220
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.991924
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.477687
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.276920
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.080239
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.225569
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.340871
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.064625
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.245584
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.035868
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.045222
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.859432
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.117558
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9644, Accuracy: 1609/2500 (64%)
#
# Doing local model validation for collaborator Chandler:                 0.6435999870300293
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.9791, Accuracy: 1622/2500 (65%)
#
# Bangalore value of 0.6488000154495239
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.131363
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.163609
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.129370
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.978801
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.961704
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.345842
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.170962
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.281902
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.111060
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.143059
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.679244
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.150559
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.366695
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.083554
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.051942
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.111950
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.151168
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.243757
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.276035
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.904392
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8842, Accuracy: 1715/2500 (69%)
#
# Doing local model validation for collaborator Bangalore:                 0.6859999895095825
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6430000066757202
# Average training loss = 1.0558814853429794
# Average local model validation values =             0.6597999930381775
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.9343, Accuracy: 1687/2500 (67%)
#
# Portland value of 0.6747999787330627
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.942410
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.969774
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.210291
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.749153
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.951142
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.970769
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.181209
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.102666
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.292425
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.978096
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.104953
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.134887
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.203364
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.989959
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.087135
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.071421
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.246320
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.878271
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.087887
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.014799
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9210, Accuracy: 1722/2500 (69%)
#
# Doing local model validation for collaborator Portland:                 0.6887999773025513
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.9246, Accuracy: 1687/2500 (67%)
#
# Seattle value of 0.6747999787330627
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.256594
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.041125
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.115782
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.882063
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.473490
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.085988
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.177793
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.126196
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.199124
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.118178
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.087558
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.938833
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.107502
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.054832
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.188838
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.883660
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.938075
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.154651
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.103114
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.113410
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9161, Accuracy: 1692/2500 (68%)
#
# Doing local model validation for collaborator Seattle:                 0.676800012588501
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.9298, Accuracy: 1651/2500 (66%)
#
# Chandler value of 0.6603999733924866
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.106383
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.826474
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.931555
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.168574
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.925867
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.986689
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.996194
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.099406
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.290305
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.220878
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.067581
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.252667
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.040049
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.984148
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.305987
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.050775
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.177090
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.098010
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.874177
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.181383
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8911, Accuracy: 1700/2500 (68%)
#
# Doing local model validation for collaborator Chandler:                 0.6800000071525574
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.8842, Accuracy: 1715/2500 (69%)
#
# Bangalore value of 0.6859999895095825
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.895806
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.072964
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.121967
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.717178
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.629476
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.977172
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.072942
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.090858
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.016862
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.016310
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.063114
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.985068
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.069420
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.069604
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.023534
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.729427
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.120757
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.950638
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.006629
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.808688
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8881, Accuracy: 1730/2500 (69%)
#
# Doing local model validation for collaborator Bangalore:                 0.6919999718666077
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6739999800920486
# Average training loss = 1.0295701324939728
# Average local model validation values =             0.6843999922275543
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.8941, Accuracy: 1745/2500 (70%)
#
# Portland value of 0.6980000138282776
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.188501
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.869508
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.006470
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.852256
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.097313
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.098999
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.052533
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.924666
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.135060
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.038635
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.094855
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.867272
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.193260
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.995436
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.758585
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.059008
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.777453
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.039024
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.900173
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.085765
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8686, Accuracy: 1758/2500 (70%)
#
# Doing local model validation for collaborator Portland:                 0.7031999826431274
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.9247, Accuracy: 1705/2500 (68%)
#
# Seattle value of 0.6819999814033508
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.980647
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.827735
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.375151
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.115174
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.947076
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.786817
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.889758
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.119925
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.773835
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.106412
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.001371
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.986026
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.958344
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.032569
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.111305
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.893066
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.279906
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.132683
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.982421
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.932399
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9007, Accuracy: 1725/2500 (69%)
#
# Doing local model validation for collaborator Seattle:                 0.6899999976158142
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.9288, Accuracy: 1680/2500 (67%)
#
# Chandler value of 0.671999990940094
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.871463
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.797224
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.917206
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.196528
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.832044
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.987524
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.050880
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.036423
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.192585
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.936308
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.265533
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.262599
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.033527
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.754091
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.984482
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.948442
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.007002
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.335991
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.054284
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.122194
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8564, Accuracy: 1752/2500 (70%)
#
# Doing local model validation for collaborator Chandler:                 0.7008000016212463
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.8881, Accuracy: 1730/2500 (69%)
#
# Bangalore value of 0.6919999718666077
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.898922
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.812312
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.835152
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.832679
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.909838
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.037240
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.033512
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.780554
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.143842
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.989733
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.949869
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.923943
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.990742
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.790417
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.074990
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.910574
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.863979
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.012654
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.190383
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.120176
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8658, Accuracy: 1741/2500 (70%)
#
# Doing local model validation for collaborator Bangalore:                 0.696399986743927
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6859999895095825
# Average training loss = 1.0651334524154663
# Average local model validation values =             0.6975999921560287
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.8924, Accuracy: 1732/2500 (69%)
#
# Portland value of 0.692799985408783
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.971683
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.257916
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.097711
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.035442
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.012833
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.246431
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.106288
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.258644
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.911259
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.949862
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.052264
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.300816
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.065525
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.848485
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.788714
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.004365
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.223396
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.927199
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.971252
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.130688
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8430, Accuracy: 1775/2500 (71%)
#
# Doing local model validation for collaborator Portland:                 0.7099999785423279
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.9194, Accuracy: 1713/2500 (69%)
#
# Seattle value of 0.6851999759674072
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.946684
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.869562
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.918611
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.797600
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.158822
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.012178
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.054821
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.013530
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.145566
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.219488
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.976622
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.857420
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.132248
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.016880
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.960000
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.168421
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.855585
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.917398
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.893132
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.955256
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8760, Accuracy: 1737/2500 (69%)
#
# Doing local model validation for collaborator Seattle:                 0.6948000192642212
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.8936, Accuracy: 1705/2500 (68%)
#
# Chandler value of 0.6819999814033508
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.225242
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.871378
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.025642
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.063655
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.986879
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.079540
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.814047
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.022178
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.083212
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.987846
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.726109
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.004270
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.952676
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.950277
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.979826
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.045217
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.953151
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.177920
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.895105
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.269053
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8487, Accuracy: 1740/2500 (70%)
#
# Doing local model validation for collaborator Chandler:                 0.6959999799728394
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.8658, Accuracy: 1741/2500 (70%)
#
# Bangalore value of 0.696399986743927
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.169877
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.813206
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.844669
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.052373
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.856480
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.912970
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.012705
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.136213
# ...
# Test set: Avg. loss: 0.7987, Accuracy: 1806/2500 (72%)
#
# Bangalore value of 0.7224000096321106
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.958663
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.003059
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.843941
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.973046
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.840777
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.186034
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.965511
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.968545
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.074504
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.155313
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.165873
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.735354
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.838462
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.774299
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.676732
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.998367
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.792527
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.079035
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.902721
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.797271
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7779, Accuracy: 1824/2500 (73%)
#
# Doing local model validation for collaborator Bangalore:                 0.7296000123023987
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7098999917507172
# Average training loss = 0.8822828084230423
# Average local model validation values =             0.711899995803833
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.7840, Accuracy: 1831/2500 (73%)
#
# Portland value of 0.7324000000953674
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.818632
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.846742
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.948152
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.895653
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.174514
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.961810
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.202215
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.135909
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.944486
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.893460
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.081832
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.907341
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.967339
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.051217
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.839731
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.236681
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.151605
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.926011
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.872898
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.888532
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8176, Accuracy: 1800/2500 (72%)
#
# Doing local model validation for collaborator Portland:                 0.7200000286102295
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.8189, Accuracy: 1792/2500 (72%)
#
# Seattle value of 0.7167999744415283
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.929107
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.698356
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.086587
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.912495
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.938147
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.015809
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.061430
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.987883
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.831504
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.974853
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.177305
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.032085
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.351406
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.874105
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.952049
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.740996
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.022233
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.872301
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.991238
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.872804
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8002, Accuracy: 1821/2500 (73%)
#
# Doing local model validation for collaborator Seattle:                 0.7283999919891357
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.8152, Accuracy: 1785/2500 (71%)
#
# Chandler value of 0.7139999866485596
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.847651
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.045350
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.001730
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.840336
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.020782
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.960863
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.863957
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.731182
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.071659
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.838205
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.870487
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.886952
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.809023
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.748114
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.772841
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.867716
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.863813
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.968450
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.836906
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.963408
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7895, Accuracy: 1814/2500 (73%)
#
# Doing local model validation for collaborator Chandler:                 0.725600004196167
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.7779, Accuracy: 1824/2500 (73%)
#
# Bangalore value of 0.7296000123023987
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.889782
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.973404
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.107795
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.877580
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.679407
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.012129
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.701816
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.113519
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.980929
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.797672
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.068738
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.936915
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.834626
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.911884
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.946787
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.006847
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.985157
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.985758
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.903285
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.727475
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7661, Accuracy: 1848/2500 (74%)
#
# Doing local model validation for collaborator Bangalore:                 0.7391999959945679
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7231999933719635
# Average training loss = 0.863054633140564
# Average local model validation values =             0.728300005197525
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.7748, Accuracy: 1844/2500 (74%)
#
# Portland value of 0.7376000285148621
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.259325
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.758605
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.883287
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.777340
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.919715
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.830292
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.053828
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.821730
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.890777
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.773269
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.188818
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.900864
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.908356
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.840737
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.731888
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.690014
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.924000
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.893973
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.822068
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.957920
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7685, Accuracy: 1837/2500 (73%)
#
# Doing local model validation for collaborator Portland:                 0.7347999811172485
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.8021, Accuracy: 1803/2500 (72%)
#
# Seattle value of 0.7211999893188477
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.189922
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.021462
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.814022
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.050260
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.097938
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.767306
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.844941
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.915118
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.060628
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.880137
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.026072
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.837240
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.064055
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.309529
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.820157
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.990078
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.931773
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.773091
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.710175
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.046630
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8263, Accuracy: 1787/2500 (71%)
#
# Doing local model validation for collaborator Seattle:                 0.7148000001907349
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.7970, Accuracy: 1799/2500 (72%)
#
# Chandler value of 0.7196000218391418
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.920773
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.967965
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.792186
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.077854
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.983944
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.861640
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.752444
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.897177
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.005595
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.081769
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.954261
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.780727
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.913548
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.916824
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.172158
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.771369
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.814926
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.019895
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.858132
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.836295
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7948, Accuracy: 1791/2500 (72%)
#
# Doing local model validation for collaborator Chandler:                 0.7164000272750854
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.7661, Accuracy: 1848/2500 (74%)
#
# Bangalore value of 0.7391999959945679
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.905826
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.896071
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.681743
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.920587
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.039883
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.566660
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.874239
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.600217
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.812387
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.645242
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.908355
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.947744
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.015025
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.836894
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.864562
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.793519
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.856147
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.891845
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.007391
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.735563
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7537, Accuracy: 1853/2500 (74%)
#
# Doing local model validation for collaborator Bangalore:                 0.7411999702453613
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7294000089168549
# Average training loss = 0.8941020965576172
# Average local model validation values =             0.7267999947071075
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling end
# This is the end of the flow
# Saving data artifacts for end
# Saved data artifacts for end

# %%
print(
    f'Sample of the final model weights: {flflow.model.state_dict()["conv1.weight"][0]}'
)

print(
    f"\nFinal aggregated model accuracy for {flflow.rounds} rounds of training: \
        {flflow.aggregated_model_accuracy}"
)
# Out:
# Sample of the final model weights: tensor([[[-0.0145,  0.0039,  0.0102],
#          [-0.0523,  0.0303,  0.0802],
#          [ 0.0495, -0.0267,  0.1297]],
#
#         [[-0.0949,  0.0476,  0.0694],
#          [-0.1488,  0.0469,  0.1080],
#          [-0.1946, -0.0422,  0.0222]],
#
#         [[-0.0294,  0.0298,  0.1073],
#          [-0.0938, -0.0925,  0.1693],
#          [-0.0752, -0.0937,  0.2290]]], device='mps:0')
#
# Final aggregated model accuracy for 10 rounds of training:         0.7294000089168549
