# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Importation des bibliothèques](#toc1_)
#   - [Importation des paquets ou modules de la bibliothèque OpenFL](#toc1_1_)
#   - [Importation des paquets ou modules de la bibliothèque PyTorch](#toc1_2_)
#   - [Importation d’autres paquets ou modules requis](#toc1_3_)
# - [Définition du modèle d‘entraînement](#toc2_)
#   - [Définition des chargeurs de données](#toc2_1_)
#   - [Définition du modèle de réseau CNN](#toc2_2_)
#   - [Définition de la fonction d'inférence utilisée dans le test](#toc2_3_)
# - [Définition des règles de l'apprentissage fédéré](#toc3_)
#   - [Méthode de calcul de la moyenne des poids d'apprentissage fédéré](#toc3_1_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Importation des bibliothèques](#toc0_)
#
# ## <a id='toc1_1_'></a>[Importation des paquets ou modules de la bibliothèque OpenFL](#toc0_)

# %%
from openfl.experimental.workflow.interface import Aggregator, Collaborator, FLSpec
from openfl.experimental.workflow.placement import aggregator, collaborator
from openfl.experimental.workflow.runtime import LocalRuntime

# %% [markdown]
# ## <a id='toc1_2_'></a>[Importation des paquets ou modules de la bibliothèque PyTorch](#toc0_)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader

from torchsummary import summary

from torchvision import datasets, transforms

# %% [markdown]
# ## <a id='toc1_3_'></a>[Importation d’autres paquets ou modules requis](#toc0_)

# %%
from copy import deepcopy

import numpy as np

from termcolor import cprint

# %% [markdown]
# # <a id='toc2_'></a>[Définition du modèle d‘entraînement](#toc0_)
#
# ## <a id='toc2_1_'></a>[Définition des chargeurs de données](#toc0_)

# %%
transform = transforms.Compose(
    [
        transforms.Resize((32, 32)),
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
    ]
)

cifar10_train = datasets.CIFAR10(
    "/tmp/files/",
    train=True,
    download=True,
    transform=transform,
)

cifar10_test = datasets.CIFAR10(
    "/tmp/files/",
    train=False,
    download=True,
    transform=transform,
)

# %% [markdown]
# ## <a id='toc2_2_'></a>[Définition du modèle de réseau CNN](#toc0_)

# %%
class LeNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, 1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, 3, 1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, 3, 1, padding=1)
        self.fc1 = nn.Linear(4 * 4 * 64, 500)
        self.dropout1 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(500, 10)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, 4 * 4 * 64)
        x = F.relu(self.fc1(x))
        x = self.dropout1(x)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
model = LeNet()
summary(model, next(iter(cifar10_test))[0].shape)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 32]             448
#             Conv2d-2           [-1, 32, 16, 16]           4,640
#             Conv2d-3             [-1, 64, 8, 8]          18,496
#             Linear-4                  [-1, 500]         512,500
#            Dropout-5                  [-1, 500]               0
#             Linear-6                   [-1, 10]           5,010
# ================================================================
# Total params: 541,094
# Trainable params: 541,094
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.23
# Params size (MB): 2.06
# Estimated Total Size (MB): 2.30
# ----------------------------------------------------------------

# %%
def count_parameters(model):
    length = 67
    names = [n for (n, p) in model.named_parameters() if p.requires_grad]
    name = "total parameters"
    names.append(name)
    max_length = max(map(len, names))
    formatted_names = [f"{f'  {n} ':.<{max_length + 3}}" for n in names]
    params = [p.numel() for p in model.parameters() if p.requires_grad]
    params.append(sum(params))
    formatted_params = [f"{f' {p}  ':.>{length - max_length - 3}}" for p in params]

    for n, p in zip(formatted_names[:-1], formatted_params[:-1]):
        cprint((n + p), "magenta")
    cprint(" " + "_" * (length - 2) + " ", "magenta")
    cprint(
        (formatted_names[-1] + formatted_params[-1]),
        "magenta",
        end="\n\n",
    )

    return names, params


names, params = count_parameters(model)
# Out:
#   conv1.weight .............................................. 432
#   conv1.bias ................................................. 16
#   conv2.weight ............................................. 4608
#   conv2.bias ................................................. 32
#   conv3.weight ............................................ 18432
#   conv3.bias ................................................. 64
#   fc1.weight ............................................. 512000
#   fc1.bias .................................................. 500
#   fc2.weight ............................................... 5000
#   fc2.bias ................................................... 10
#  _________________________________________________________________
#   total parameters ....................................... 541094

# %% [markdown]
# ## <a id='toc2_3_'></a>[Définition de la fonction d'inférence utilisée dans le test](#toc0_)

# %%
def inference(network, test_loader):
    # Mettre le module en mode évaluation.
    network.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = network(data)
            test_loss += F.nll_loss(output, target, reduction="sum").item()
            pred = output.data.max(dim=1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    test_loss /= len(test_loader.dataset)
    cprint(
        "Test set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)".format(
            test_loss,
            correct,
            len(test_loader.dataset),
            100.0 * correct / len(test_loader.dataset),
        ),
        "magenta",
        attrs=["underline"],
        end="\n\n",
    )
    accuracy = float(correct / len(test_loader.dataset))
    return accuracy

# %%
test_loader = DataLoader(cifar10_test, batch_size=500, shuffle=False)

inference(model, test_loader)
# Out:
# Test set: Avg. loss: 2.3023, Accuracy: 1050/10000 (10%)
# 0.10499999672174454

# %% [markdown]
# # <a id='toc3_'></a>[Définition des règles de l'apprentissage fédéré](#toc0_)
#
# ## <a id='toc3_1_'></a>[Méthode de calcul de la moyenne des poids d'apprentissage fédéré](#toc0_)

# %%
def FedAvg(models, weights=None):
    new_model = models[0]
    state_dicts = [model.state_dict() for model in models]
    state_dict = new_model.state_dict()
    for key in models[1].state_dict():
        state_dict[key] = torch.from_numpy(
            np.average(
                [state[key].numpy() for state in state_dicts], axis=0, weights=weights
            )
        )
    new_model.load_state_dict(state_dict)
    return new_model

# %%
keys = [k for k in model.state_dict().keys()]
names = [n for (n, p) in model.named_parameters() if p.requires_grad]
keys == names
# Out:
# True

# %%
# batch_size_train = 64
# batch_size_test = 1000
learning_rate = 0.01
log_interval = 10
momentum = 0.5


# random_seed = 1
# torch.backends.cudnn.enabled = False
# torch.manual_seed(random_seed)


class FederatedFlow(FLSpec):

    def __init__(self, model=None, optimizer=None, rounds=3, **kwargs):
        super().__init__(**kwargs)
        # Importe un modèle personnalisé et ajoute le bon algorithme d’optimisation pour ce dernier.
        if model is not None:
            self.model = model
            self.optimizer = optimizer
        # Chargez le modèle `Net()` et configurez l'optimiseur pour qu'il s'applique uniquement à ce
        # modèle.
        else:
            self.model = Net()
            self.optimizer = optim.SGD(
                self.model.parameters(), lr=learning_rate, momentum=momentum
            )
        self.rounds = rounds

    # Un agrégateur est le nœud central de l'apprentissage fédéré.

    # L'agrégateur commence par un modèle et un optimiseur transmis de manière facultative.

    # L'agrégateur commence le flux avec la tâche de `start`, où la liste des collaborateurs est
    # extraite de l'exécution (`self.collaborators = self.runtime.collaborators`) et est ensuite
    # utilisée comme liste de participants pour exécuterla tâche énumérée dans `self.next`,
    # `aggregated_model_validation`.
    @aggregator
    def start(self):
        cprint(f"Performing initialization for model", "black", attrs=["bold"])
        self.collaborators = self.runtime.collaborators
        self.private = 10
        self.current_round = 0
        self.next(
            self.aggregated_model_validation,
            foreach="collaborators",
            exclude=["private"],
        )

    # Le modèle, l'optimiseur et tout ce qui n'est pas explicitement exclu de la fonction suivante
    # seront transmis de la fonction de `start` de l'agrégateur à la tâche
    # `aggregated_model_validation` du collaborateur.

    # L’endroit où les tâches sont exécutées est déterminé par le décorateur de placement qui
    # précède chaque définition de tâche (`@aggregator` ou `@collaborator`).

    # Une fois que chaque collaborateur (défini dans l’exécution) a terminé la tâche
    # `aggregated_model_validation`, il transmet son état actuel à la tâche `train`, de `train` à
    # `local_model_validation`, et enfin à `join` à l'agrégateur.

    # C'est au niveau de `join` qu'une moyenne des poids des modèles est calculée et que le tour
    # suivant peut commencer.
    @collaborator
    def aggregated_model_validation(self):
        cprint(
            f"Performing aggregated model validation for collaborator {self.input}",
            "red",
            attrs=["bold"],
        )
        self.agg_validation_score = inference(self.model, self.test_loader)
        cprint(
            f"{self.input} value of {self.agg_validation_score}",
            "red",
            attrs=["underline"],
        )
        self.next(self.train)

    @collaborator
    def train(self):
        if model is not None:
            self.model = model
            self.optimizer = optimizer
        else:
            self.model = Net()
            self.optimizer = optim.SGD(
                self.model.parameters(), lr=learning_rate, momentum=momentum
            )
        self.model.train()
        for batch_idx, (data, target) in enumerate(self.train_loader):
            self.optimizer.zero_grad()
            output = self.model(data)
            loss = F.nll_loss(output, target)
            loss.backward()
            self.optimizer.step()
            if batch_idx % log_interval == 0:
                cprint(
                    "Train Epoch: 1 [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                        batch_idx * len(data),
                        len(self.train_loader.dataset),
                        100.0 * batch_idx / len(self.train_loader),
                        loss.item(),
                    ),
                    "yellow",
                )
                self.loss = loss.item()
                torch.save(self.model.state_dict(), "model.pth")
                torch.save(self.optimizer.state_dict(), "optimizer.pth")
        self.training_completed = True
        self.next(self.local_model_validation)

    @collaborator
    def local_model_validation(self):
        self.local_validation_score = inference(self.model, self.test_loader)
        cprint(
            f"Doing local model validation for collaborator {self.input}: \
                {self.local_validation_score}",
            "white",
        )
        self.next(self.join, exclude=["training_completed"])

    @aggregator
    def join(self, inputs):
        self.average_loss = sum(input.loss for input in inputs) / len(inputs)
        self.aggregated_model_accuracy = sum(
            input.agg_validation_score for input in inputs
        ) / len(inputs)
        self.local_model_accuracy = sum(
            input.local_validation_score for input in inputs
        ) / len(inputs)
        cprint(
            f"Average aggregated model validation values = \
                {self.aggregated_model_accuracy}",
            "green",
        )
        cprint(f"Average training loss = {self.average_loss}", "green")
        cprint(
            f"Average local model validation values = \
            {self.local_model_accuracy}",
            "green",
        )
        self.model = FedAvg([input.model for input in inputs])
        self.optimizer = [input.optimizer for input in inputs][0]
        self.current_round += 1
        if self.current_round < self.rounds:
            self.next(
                self.aggregated_model_validation,
                foreach="collaborators",
                exclude=["private"],
            )
        else:
            self.next(self.end)

    @aggregator
    def end(self):
        cprint(f"This is the end of the flow", "black")
# Out:
# Aggregator step "start" registered
# Collaborator step "aggregated_model_validation" registered
# Collaborator step "train" registered
# Collaborator step "local_model_validation" registered
# Aggregator step "join" registered
# Aggregator step "end" registered

# %%
batch_size_train = 64

# Setup participants
aggregator = Aggregator()
aggregator.private_attributes = {}

# Setup collaborators with private attributes
collaborator_names = ["Portland", "Seattle", "Chandler", "Bangalore"]
collaborators = [Collaborator(name=name) for name in collaborator_names]
for idx, collaborator in enumerate(collaborators):
    local_train = deepcopy(cifar10_train)
    local_test = deepcopy(cifar10_test)
    local_train.data = cifar10_train.data[idx :: len(collaborators)]
    local_train.targets = cifar10_train.targets[idx :: len(collaborators)]
    local_test.data = cifar10_test.data[idx :: len(collaborators)]
    local_test.targets = cifar10_test.targets[idx :: len(collaborators)]
    collaborator.private_attributes = {
        "train_loader": DataLoader(
            local_train, batch_size=batch_size_train, shuffle=True
        ),
        "test_loader": DataLoader(
            local_test, batch_size=batch_size_train, shuffle=True
        ),
    }

local_runtime = LocalRuntime(
    aggregator=aggregator, collaborators=collaborators, backend="single_process"
)
print(f"Local runtime collaborators = {local_runtime.collaborators}")
# Out:
# Local runtime collaborators = ['Portland', 'Seattle', 'Chandler', 'Bangalore']

# %%
import os
if os.environ.get("USERNAME") is None:
    os.environ["USERNAME"] = "Hao"

# %%
import getpass
print(getpass.getuser())
# Out:
# Hao

# %%
model = LeNet()
learning_rate = 0.001
best_model = None
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
flflow = FederatedFlow(model, optimizer, rounds=10, checkpoint=True)
flflow.runtime = local_runtime
flflow.run()
# Out:
# Created flow FederatedFlow
#
# Calling start
# Performing initialization for model
# Saving data artifacts for start
# Saved data artifacts for start
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 2.3030, Accuracy: 182/2500 (7%)
#
# Portland value of 0.07280000299215317
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 2.301871
# Train Epoch: 1 [640/12500 (5%)]	Loss: 2.271784
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 2.219423
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 2.023301
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.963554
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.989470
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.936648
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.877537
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.910005
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.795561
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.904488
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.758278
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.706298
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.564763
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.673164
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.519150
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.646504
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.697223
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.703040
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.631739
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.5413, Accuracy: 1036/2500 (41%)
#
# Doing local model validation for collaborator Portland:                 0.41440001130104065
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 2.3033, Accuracy: 179/2500 (7%)
#
# Seattle value of 0.07159999758005142
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.654716
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.450837
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.650595
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.714682
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.486001
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.497786
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.494818
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.479244
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.686632
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.561490
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.609961
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.522578
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.481166
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.759349
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.477741
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.525184
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.340361
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.409975
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.498063
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.238208
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.4062, Accuracy: 1162/2500 (46%)
#
# Doing local model validation for collaborator Seattle:                 0.46480000019073486
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 2.3042, Accuracy: 178/2500 (7%)
#
# Chandler value of 0.07119999825954437
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.480659
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.343641
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.150564
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.269311
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.340255
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.547005
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.598577
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.292313
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.457060
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.395179
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.466003
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.501806
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.589078
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.288817
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.576498
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.306750
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.412472
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.086337
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.117629
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.267161
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.3537, Accuracy: 1268/2500 (51%)
#
# Doing local model validation for collaborator Chandler:                 0.5072000026702881
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 2.3030, Accuracy: 188/2500 (8%)
#
# Bangalore value of 0.07519999891519547
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.398954
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.521744
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.510051
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.597932
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.177508
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.476934
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.433416
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.368672
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.381276
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.153292
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.315329
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.352472
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.474498
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.220279
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.083801
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.412225
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.052871
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.506815
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.347460
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.193188
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.2738, Accuracy: 1369/2500 (55%)
#
# Doing local model validation for collaborator Bangalore:                 0.5475999712944031
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.0726999994367361
# Average training loss = 1.332574039697647
# Average local model validation values =             0.48349999636411667
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 1.2927, Accuracy: 1367/2500 (55%)
#
# Portland value of 0.5468000173568726
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.117513
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.173849
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.153283
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.346783
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.377600
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.421299
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.088399
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.265506
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.461380
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.158875
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.282712
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.267549
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.104743
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.358192
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.018385
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.181169
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.193684
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.021761
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.193417
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.383361
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1884, Accuracy: 1443/2500 (58%)
#
# Doing local model validation for collaborator Portland:                 0.5771999955177307
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 1.2965, Accuracy: 1311/2500 (52%)
#
# Seattle value of 0.524399995803833
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.256196
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.137886
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.260300
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.422382
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.330372
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.214179
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.435416
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.132666
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.327905
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.345404
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.122548
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.284347
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.124894
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.209887
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.187707
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.217453
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.130056
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.877998
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.928245
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.227394
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1550, Accuracy: 1446/2500 (58%)
#
# Doing local model validation for collaborator Seattle:                 0.5784000158309937
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 1.3082, Accuracy: 1318/2500 (53%)
#
# Chandler value of 0.5271999835968018
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.203171
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.264028
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.026071
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.199841
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.053694
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.981618
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.072312
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.053324
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.167633
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.065316
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.171780
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.923683
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.070904
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.082771
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.281121
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.286370
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.084188
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.149981
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.146412
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.050322
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.1126, Accuracy: 1477/2500 (59%)
#
# Doing local model validation for collaborator Chandler:                 0.5907999873161316
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 1.2738, Accuracy: 1369/2500 (55%)
#
# Bangalore value of 0.5475999712944031
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.201554
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.070342
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.224716
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.896911
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.202173
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.140162
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.023756
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.932094
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.066537
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.020586
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.019578
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.963013
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.232311
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.161259
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.946426
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.928525
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.022958
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.390720
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.959275
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.838001
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.0293, Accuracy: 1574/2500 (63%)
#
# Doing local model validation for collaborator Bangalore:                 0.6295999884605408
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.5364999920129776
# Average training loss = 1.1247694194316864
# Average local model validation values =             0.5939999967813492
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 1.0611, Accuracy: 1548/2500 (62%)
#
# Portland value of 0.6191999912261963
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.416965
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.965981
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.132058
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.000198
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.007489
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.762023
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.880874
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.045839
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.033826
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.850625
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.067593
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.871493
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.965738
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.990595
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.952921
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 1.045364
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.929333
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.194845
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 1.207178
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.239103
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 1.0363, Accuracy: 1572/2500 (63%)
#
# Doing local model validation for collaborator Portland:                 0.6287999749183655
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 1.0710, Accuracy: 1532/2500 (61%)
#
# Seattle value of 0.6128000020980835
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.231193
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.830994
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.899559
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.383567
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.973372
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.118510
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.936091
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.077086
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.972467
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.934715
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.037132
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.035778
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.952408
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.198541
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.061213
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.991239
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.059172
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.246915
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.974267
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.966947
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9838, Accuracy: 1603/2500 (64%)
#
# Doing local model validation for collaborator Seattle:                 0.6412000060081482
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 1.0824, Accuracy: 1520/2500 (61%)
#
# Chandler value of 0.6079999804496765
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.928086
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.052367
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.162609
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.973501
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.950525
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.904850
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.005515
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.191425
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.830492
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.057657
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.245421
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.927917
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.968432
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.190876
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.802453
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.896007
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.207891
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.951286
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.985923
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.950501
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9713, Accuracy: 1627/2500 (65%)
#
# Doing local model validation for collaborator Chandler:                 0.6507999897003174
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 1.0293, Accuracy: 1574/2500 (63%)
#
# Bangalore value of 0.6295999884605408
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.910506
# Train Epoch: 1 [640/12500 (5%)]	Loss: 1.117954
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.903354
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 1.217116
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.845859
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.835978
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.013689
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.862940
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.081750
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.968515
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.912730
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.054109
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.045676
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.871657
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 1.057459
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.886329
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.887468
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.063558
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.824829
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.770552
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9168, Accuracy: 1703/2500 (68%)
#
# Doing local model validation for collaborator Bangalore:                 0.6812000274658203
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6173999905586243
# Average training loss = 0.9817755967378616
# Average local model validation values =             0.6504999995231628
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.9632, Accuracy: 1649/2500 (66%)
#
# Portland value of 0.659600019454956
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.864662
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.840739
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.892315
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.901955
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.761951
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.771586
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.888839
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.024704
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.717137
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.829232
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.160748
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.842192
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.974860
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.747472
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.841797
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.941843
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.944089
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.971424
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.892922
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.784157
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9364, Accuracy: 1697/2500 (68%)
#
# Doing local model validation for collaborator Portland:                 0.6787999868392944
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.9470, Accuracy: 1655/2500 (66%)
#
# Seattle value of 0.6620000004768372
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.844864
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.754894
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.770661
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.938812
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.980193
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.109166
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.754753
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.712624
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.784567
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 1.060254
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.040150
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 1.059814
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.859662
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.823768
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.852515
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.912993
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 1.169960
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.087483
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.944982
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.769357
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9154, Accuracy: 1708/2500 (68%)
#
# Doing local model validation for collaborator Seattle:                 0.6832000017166138
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.9474, Accuracy: 1648/2500 (66%)
#
# Chandler value of 0.6592000126838684
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.976909
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.832452
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 1.032401
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.785965
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.136670
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 1.111917
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 1.080556
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.960957
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.881494
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.916520
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.041636
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.997386
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.837039
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.721957
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.832286
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.938083
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.968875
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.737502
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.925870
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.705336
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8884, Accuracy: 1704/2500 (68%)
#
# Doing local model validation for collaborator Chandler:                 0.6815999746322632
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.9168, Accuracy: 1703/2500 (68%)
#
# Bangalore value of 0.6812000274658203
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 1.091063
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.881419
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.822946
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.740807
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 1.047399
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.772273
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.986914
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.983097
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.596867
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.999776
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.769067
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.753823
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.934452
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.979448
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.829428
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.869766
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.832957
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 1.000437
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.827806
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.858540
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8777, Accuracy: 1744/2500 (70%)
#
# Doing local model validation for collaborator Bangalore:                 0.6976000070571899
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6655000150203705
# Average training loss = 0.7793475538492203
# Average local model validation values =             0.6852999925613403
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.8940, Accuracy: 1751/2500 (70%)
#
# Portland value of 0.7003999948501587
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.627952
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.705777
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.833165
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.858347
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.902073
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.840686
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.801086
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.951236
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.824182
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.962375
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.947446
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.688285
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.772590
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.020955
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.730360
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.741593
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.609186
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.799181
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.560154
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.800433
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.9214, Accuracy: 1719/2500 (69%)
#
# Doing local model validation for collaborator Portland:                 0.6876000165939331
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.8826, Accuracy: 1738/2500 (70%)
#
# Seattle value of 0.6952000260353088
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.968101
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.938008
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.969267
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.538787
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.804897
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.805218
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.840734
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 1.114258
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.732760
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.771306
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 1.117429
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.884135
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 1.011934
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 1.070555
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.935284
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.654642
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.850696
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.916396
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.744979
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.188664
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8708, Accuracy: 1711/2500 (68%)
#
# Doing local model validation for collaborator Seattle:                 0.6844000220298767
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.9138, Accuracy: 1705/2500 (68%)
#
# Chandler value of 0.6819999814033508
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.681422
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.806285
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.856270
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.951762
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.729789
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.711916
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.885595
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.847512
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.825630
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.841795
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.934526
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.971444
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.509049
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.773881
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.890480
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.632833
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.758037
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.813275
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.744938
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.702513
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8292, Accuracy: 1765/2500 (71%)
#
# Doing local model validation for collaborator Chandler:                 0.7059999704360962
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.8777, Accuracy: 1744/2500 (70%)
#
# Bangalore value of 0.6976000070571899
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.873412
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.748165
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.920459
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.708273
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.869835
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.600989
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.672983
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.604160
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.680098
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.603160
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.871948
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.907470
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.810319
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.977649
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.714249
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.988121
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.707222
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.596239
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.574637
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.753236
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7982, Accuracy: 1834/2500 (73%)
#
# Doing local model validation for collaborator Bangalore:                 0.7336000204086304
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.6938000023365021
# Average training loss = 0.8612114638090134
# Average local model validation values =             0.7029000073671341
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.8290, Accuracy: 1798/2500 (72%)
#
# Portland value of 0.7192000150680542
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.630786
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.897391
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.709327
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.705519
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.722983
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.776558
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.929526
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.719013
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.744408
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.631607
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.774974
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.760605
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.574431
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.858171
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.779895
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.594603
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.784836
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.924904
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.735101
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.560420
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8251, Accuracy: 1821/2500 (73%)
#
# Doing local model validation for collaborator Portland:                 0.7283999919891357
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.8066, Accuracy: 1793/2500 (72%)
#
# Seattle value of 0.717199981212616
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.758274
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.679978
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.885018
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.697965
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.794616
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.772759
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.714343
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.710429
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.969286
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.429924
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.902493
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.999197
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.968599
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.793987
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.723749
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.595849
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.575049
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.734107
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.676830
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.843188
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8187, Accuracy: 1769/2500 (71%)
#
# Doing local model validation for collaborator Seattle:                 0.7075999975204468
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.8244, Accuracy: 1768/2500 (71%)
#
# Chandler value of 0.7071999907493591
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.764238
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.681016
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.622830
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.764515
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.627357
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.759178
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.617516
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.717308
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.709593
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.897492
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.459777
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.565623
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.639819
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.610711
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.804768
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.721889
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.915448
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.740124
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.690618
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.664561
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8042, Accuracy: 1779/2500 (71%)
#
# Doing local model validation for collaborator Chandler:                 0.7116000056266785
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.7982, Accuracy: 1834/2500 (73%)
#
# Bangalore value of 0.7336000204086304
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.766231
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.628383
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.805332
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.720380
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.694766
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.724812
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.704080
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.911094
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 1.006610
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.636496
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.636926
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.809261
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.675779
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.584912
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.649580
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.638598
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.619164
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.728359
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.512961
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.801046
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8160, Accuracy: 1802/2500 (72%)
#
# Doing local model validation for collaborator Bangalore:                 0.72079998254776
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7193000018596649
# Average training loss = 0.7173036634922028
# Average local model validation values =             0.7170999944210052
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.8395, Accuracy: 1811/2500 (72%)
#
# Portland value of 0.724399983882904
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.765692
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.755981
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.734960
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.709263
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.804526
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.594736
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.730869
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.446026
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.674002
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.852628
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.685187
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.751282
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.766411
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.838269
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.893645
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.826475
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.628549
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.594434
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.682949
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.627857
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8051, Accuracy: 1833/2500 (73%)
#
# Doing local model validation for collaborator Portland:                 0.7332000136375427
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.8167, Accuracy: 1780/2500 (71%)
#
# Seattle value of 0.7120000123977661
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.652475
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.522499
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.760149
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.568479
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.673110
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.606195
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.666458
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.713854
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.730264
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.767002
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.763034
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.556446
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.894244
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.443027
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.559758
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.409995
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.416971
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.735455
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.623457
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.665375
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7864, Accuracy: 1816/2500 (73%)
#
# Doing local model validation for collaborator Seattle:                 0.7264000177383423
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.8390, Accuracy: 1767/2500 (71%)
#
# Chandler value of 0.7067999839782715
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.582794
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.765196
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.893953
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.683353
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.758455
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.475333
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.496803
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.622480
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.726622
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.578302
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.799613
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.655361
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.606310
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.837654
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.694143
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.583782
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.650217
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.810668
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.609671
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 1.100885
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8214, Accuracy: 1757/2500 (70%)
#
# Doing local model validation for collaborator Chandler:                 0.7027999758720398
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.8160, Accuracy: 1802/2500 (72%)
#
# Bangalore value of 0.72079998254776
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.505442
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.965380
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.738576
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.693632
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.443136
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.558129
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.655069
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.701438
# ...
# Test set: Avg. loss: 0.7780, Accuracy: 1843/2500 (74%)
#
# Bangalore value of 0.7372000217437744
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.684971
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.518338
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.583543
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.523158
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.547888
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.706388
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.555878
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.646746
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.612117
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.744812
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.659980
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.623219
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.521329
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.563218
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.595487
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.728189
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.456866
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.678945
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.420855
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.500277
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7587, Accuracy: 1863/2500 (75%)
#
# Doing local model validation for collaborator Bangalore:                 0.745199978351593
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7334000170230865
# Average training loss = 0.5931453108787537
# Average local model validation values =             0.7365999817848206
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.7868, Accuracy: 1868/2500 (75%)
#
# Portland value of 0.7472000122070312
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.612209
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.467613
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.886382
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.734644
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.479618
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.653327
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.433133
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.901512
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.648274
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.586418
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.723008
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.695083
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.532803
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.554420
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.442978
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.713216
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.635045
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.433515
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.571899
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.555370
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7707, Accuracy: 1871/2500 (75%)
#
# Doing local model validation for collaborator Portland:                 0.7483999729156494
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.7766, Accuracy: 1839/2500 (74%)
#
# Seattle value of 0.7355999946594238
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.362292
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.601443
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.668180
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.485626
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.698218
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.556194
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.689329
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.344845
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.568830
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.578844
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.499338
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.379466
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.624740
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.512446
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.533959
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.650372
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.527205
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.641349
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.527864
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.476728
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7763, Accuracy: 1846/2500 (74%)
#
# Doing local model validation for collaborator Seattle:                 0.7383999824523926
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.7817, Accuracy: 1816/2500 (73%)
#
# Chandler value of 0.7264000177383423
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.576978
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.758626
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.489344
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.606989
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.451171
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.537619
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.483353
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.647157
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.721138
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.368937
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.544638
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.633898
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.474554
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.557319
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.488099
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.816728
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.716919
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.673311
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.356561
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.634816
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7724, Accuracy: 1836/2500 (73%)
#
# Doing local model validation for collaborator Chandler:                 0.7343999743461609
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.7587, Accuracy: 1863/2500 (75%)
#
# Bangalore value of 0.745199978351593
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.470848
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.630365
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.592119
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.406162
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.446196
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.527726
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.597757
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.528976
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.472340
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.484697
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.493744
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.541580
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.665574
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.554964
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.518662
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.555866
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.533296
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.498610
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.521653
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.699521
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7523, Accuracy: 1890/2500 (76%)
#
# Doing local model validation for collaborator Bangalore:                 0.7559999823570251
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.7386000007390976
# Average training loss = 0.5916089862585068
# Average local model validation values =             0.744299978017807
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Portland
# Test set: Avg. loss: 0.7720, Accuracy: 1872/2500 (75%)
#
# Portland value of 0.7487999796867371
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.752396
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.402514
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.468483
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.536294
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.451177
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.575868
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.408555
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.714840
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.570279
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.540833
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.506548
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.695820
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.308029
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.542182
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.586027
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.645089
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.594139
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.437980
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.494484
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.417753
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8209, Accuracy: 1844/2500 (74%)
#
# Doing local model validation for collaborator Portland:                 0.7376000285148621
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Seattle
# Test set: Avg. loss: 0.7951, Accuracy: 1852/2500 (74%)
#
# Seattle value of 0.7408000230789185
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.307148
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.513719
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.853923
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.673121
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.390470
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.388658
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.538164
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.519424
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.550544
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.727508
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.549219
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.525881
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.543208
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.506606
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.596211
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.656979
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.534364
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.761456
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.752225
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.324625
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7631, Accuracy: 1870/2500 (75%)
#
# Doing local model validation for collaborator Seattle:                 0.7480000257492065
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Chandler
# Test set: Avg. loss: 0.7909, Accuracy: 1804/2500 (72%)
#
# Chandler value of 0.7215999960899353
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.544072
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.454272
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.521695
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.651815
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.384095
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.424678
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.444742
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.559011
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.450489
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.391359
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.519947
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.370646
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.511424
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.551074
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.596522
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.495385
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.508615
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.611863
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.467528
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.616126
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.8061, Accuracy: 1826/2500 (73%)
#
# Doing local model validation for collaborator Chandler:                 0.730400025844574
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# Performing aggregated model validation for collaborator Bangalore
# Test set: Avg. loss: 0.7523, Accuracy: 1890/2500 (76%)
#
# Bangalore value of 0.7559999823570251
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Train Epoch: 1 [0/12500 (0%)]	Loss: 0.288132
# Train Epoch: 1 [640/12500 (5%)]	Loss: 0.485972
# Train Epoch: 1 [1280/12500 (10%)]	Loss: 0.696116
# Train Epoch: 1 [1920/12500 (15%)]	Loss: 0.612620
# Train Epoch: 1 [2560/12500 (20%)]	Loss: 0.439045
# Train Epoch: 1 [3200/12500 (26%)]	Loss: 0.387732
# Train Epoch: 1 [3840/12500 (31%)]	Loss: 0.590032
# Train Epoch: 1 [4480/12500 (36%)]	Loss: 0.364603
# Train Epoch: 1 [5120/12500 (41%)]	Loss: 0.491441
# Train Epoch: 1 [5760/12500 (46%)]	Loss: 0.546701
# Train Epoch: 1 [6400/12500 (51%)]	Loss: 0.618595
# Train Epoch: 1 [7040/12500 (56%)]	Loss: 0.406990
# Train Epoch: 1 [7680/12500 (61%)]	Loss: 0.392866
# Train Epoch: 1 [8320/12500 (66%)]	Loss: 0.487326
# Train Epoch: 1 [8960/12500 (71%)]	Loss: 0.478568
# Train Epoch: 1 [9600/12500 (77%)]	Loss: 0.540516
# Train Epoch: 1 [10240/12500 (82%)]	Loss: 0.440369
# Train Epoch: 1 [10880/12500 (87%)]	Loss: 0.402628
# Train Epoch: 1 [11520/12500 (92%)]	Loss: 0.612655
# Train Epoch: 1 [12160/12500 (97%)]	Loss: 0.703235
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# Test set: Avg. loss: 0.7537, Accuracy: 1892/2500 (76%)
#
# Doing local model validation for collaborator Bangalore:                 0.7567999958992004
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# Average aggregated model validation values =                 0.741799995303154
# Average training loss = 0.5154346972703934
# Average local model validation values =             0.7432000190019608
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling end
# This is the end of the flow
# Saving data artifacts for end
# Saved data artifacts for end

# %%
print(
    f'Sample of the final model weights: {flflow.model.state_dict()["conv1.weight"][0]}'
)

print(
    f"\nFinal aggregated model accuracy for {flflow.rounds} rounds of training: {flflow.aggregated_model_accuracy}"
)
# Out:
# Sample of the final model weights: tensor([[[-0.0845,  0.0758,  0.0977],
#          [ 0.0828,  0.0587,  0.0655],
#          [-0.0463, -0.0856,  0.0403]],
#
#         [[-0.1677, -0.1664, -0.0694],
#          [-0.0124, -0.1056, -0.0673],
#          [ 0.0343,  0.0203, -0.0043]],
#
#         [[-0.0838,  0.2007, -0.0346],
#          [-0.0408, -0.0853, -0.0837],
#          [ 0.1958, -0.0885, -0.0573]]])
#
# Final aggregated model accuracy for 10 rounds of training: 0.741799995303154
